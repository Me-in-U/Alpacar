# %%
from ultralytics import YOLO

model = YOLO("yolo11s-obb.pt")

results = model.train(
    data="custom/dataset/data.yaml", 
    epochs=150, 
    imgsz=640,
    batch=64,
    degrees=180,
    scale=0.5,
    hsv_h=0.03,
    hsv_s=0.6,
    hsv_v=1.0,      # 밝기 변화 최대치
    save_period=10   # 매 epoch마다 저장
)
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.11 torch-2.8.0.dev20250319+cu128 CUDA:0 (NVIDIA RTX 2000 Ada Generation, 16076MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/obb/train11/weights/last.pt")

results = model.train(
    data="custom/dataset/data.yaml",
    epochs=50,          # 추가 학습만큼만 지정
    imgsz=640,
    batch=64,
    degrees=180,
    scale=0.2,
    save_period=10
)
# Out:
# Ultralytics 8.3.176 🚀 Python-3.11.11 torch-2.8.0.dev20250319+cu128 CUDA:0 (NVIDIA RTX 2000 Ada Generation, 16076MiB)
# ...
